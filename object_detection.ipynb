# %% [markdown]
# #**Import the Required Libraries**

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.8/107.7 GB disk)

# %%
from ultralytics import YOLO

# %% [markdown]
# ##Setting the Current Directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/object_detection_task
# Out:
# /content/drive/MyDrive/object_detection_task

# %% [markdown]
# #**Training the Custom Model**

# %%
# %cd /content/drive/MyDrive/object_detection_task
# !yolo task=detect mode=train model=yolov8s.pt data= dataset.yaml epochs=20 imgsz=454 plots=True
# Out:
# /content/drive/MyDrive/object_detection_task
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# #**Predicting the Custom Model**

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/object_detection_task/runs/detect/train4/weights/best.pt conf=0.25 source=/content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 538.8ms
# video 1/1 (2/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 353.7ms
# video 1/1 (3/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 308.4ms
# video 1/1 (4/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 310.7ms
# video 1/1 (5/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 322.3ms
# video 1/1 (6/3305) /content/drive/MyDrive/object_detection_task/Short_Preview_Video.mp4: 288x480 (no detections), 328.9ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/object_detection_task/runs/detect/train4/weights/best.pt conf=0.25 source=/content/drive/MyDrive/object_detection_task/video_1.mp4
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 253.5ms
# video 1/1 (2/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 225.6ms
# video 1/1 (3/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 211.1ms
# video 1/1 (4/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 232.1ms
# video 1/1 (5/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 199.5ms
# video 1/1 (6/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 218.3ms
# video 1/1 (7/1232) /content/drive/MyDrive/object_detection_task/video_1.mp4: 288x480 2 persons, 201.3ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/object_detection_task/runs/detect/train4/weights/best.pt conf=0.25 source=/content/drive/MyDrive/object_detection_task/video_2.mp4 show=True
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 16 persons, 255.1ms
# video 1/1 (2/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 17 persons, 228.5ms
# video 1/1 (3/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 18 persons, 238.2ms
# video 1/1 (4/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 17 persons, 199.2ms
# video 1/1 (5/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 17 persons, 234.5ms
# video 1/1 (6/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 15 persons, 206.7ms
# video 1/1 (7/1431) /content/drive/MyDrive/object_detection_task/video_2.mp4: 288x480 16 persons, 248.1ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/object_detection_task/runs/detect/train4/weights/best.pt conf=0.25 source=/content/drive/MyDrive/object_detection_task/video_3.mp4
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 325.5ms
# video 1/1 (2/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 228.5ms
# video 1/1 (3/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 237.4ms
# video 1/1 (4/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 205.5ms
# video 1/1 (5/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 234.3ms
# video 1/1 (6/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 223.2ms
# video 1/1 (7/1051) /content/drive/MyDrive/object_detection_task/video_3.mp4: 288x480 (no detections), 194.2ms
# ...
